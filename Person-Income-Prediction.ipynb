# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('adult.data',header=None)  #here header gives title of the all columns as numbers

# %%
df
# Out:
#        0                  1       2            3   4                    5   \
# 0      39          State-gov   77516    Bachelors  13        Never-married
# 1      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 2      38            Private  215646      HS-grad   9             Divorced
# 3      53            Private  234721         11th   7   Married-civ-spouse
# 4      28            Private  338409    Bachelors  13   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32556  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910      HS-grad   9              Widowed
# 32559  22            Private  201490      HS-grad   9        Never-married
# 32560  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
# ...

# %%
df.columns=["age","workclass","fnwgt","education","education-num","martial-status","occupation","relationship","race","sex","capital-gain","capital-loss","hours-per-week","native-country","target"]

# %%
df
# Out:
#        age          workclass   fnwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             martial-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnwgt           32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   martial-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  target          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age         fnwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.describe(include='all') #here we can see 22696 people are in private
# Out:
#                  age workclass         fnwgt education  education-num  \
# count   32561.000000     32561  3.256100e+04     32561   32561.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#              martial-status       occupation relationship    race    sex  \
# ...

# %%
df.head()  #here we can see upto top of 5 values
# Out:
#    age          workclass   fnwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         martial-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  target
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.tail()          #here we can see bottom upto 5 values
# Out:
#        age      workclass   fnwgt    education  education-num  \
# 32556   27        Private  257302   Assoc-acdm             12
# 32557   40        Private  154374      HS-grad              9
# 32558   58        Private  151910      HS-grad              9
# 32559   22        Private  201490      HS-grad              9
# 32560   52   Self-emp-inc  287927      HS-grad              9
#
#             martial-status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loss  hours-per-week  native-country  target
# ...

# %%
df.head(10)       #here we can see upto 10 values
# Out:
#    age          workclass   fnwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            martial-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
df['workclass']
# Out:
# 0                State-gov
# 1         Self-emp-not-inc
# 2                  Private
# 3                  Private
# 4                  Private
#                ...
# 32556              Private
# 32557              Private
# 32558              Private
# 32559              Private
# 32560         Self-emp-inc
# Name: workclass, Length: 32561, dtype: object

# %%
np.unique(df['workclass'])     #here we can print unique items not repeating values
# Out:
# array([' ?', ' Federal-gov', ' Local-gov', ' Never-worked', ' Private',
#        ' Self-emp-inc', ' Self-emp-not-inc', ' State-gov', ' Without-pay'],
#       dtype=object)

# %%
df['workclass'].unique()        #it is another type to execute
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df['native-country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
df.target.value_counts()      #to count the values of target columns above 50 and less than 50
# Out:
#  <=50K    24720
#  >50K      7841
# Name: target, dtype: int64

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.boxplot()
plt.show()

# %%
df[["age"]].boxplot()
plt.show()

# %%
sns.countplot(df.target)
plt.show()
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
np.unique(df['workclass'])
# Out:
# array([' ?', ' Federal-gov', ' Local-gov', ' Never-worked', ' Private',
#        ' Self-emp-inc', ' Self-emp-not-inc', ' State-gov', ' Without-pay'],
#       dtype=object)

# %%
df.workclass.value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
for col in df.columns:
    for i in range(len(df[col])):
        if df[col][i]==' ?':
            df[col][i]=np.nan
# Out:
# C:\Users\tyate\AppData\Local\Temp\ipykernel_11248\4234127604.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col][i]=np.nan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnwgt           32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   martial-status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  31978 non-null  object
#  14  target          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isna()
# Out:
#          age  workclass  fnwgt  education  education-num  martial-status  \
# 0      False      False  False      False          False           False
# 1      False      False  False      False          False           False
# 2      False      False  False      False          False           False
# 3      False      False  False      False          False           False
# 4      False      False  False      False          False           False
# ...      ...        ...    ...        ...            ...             ...
# 32556  False      False  False      False          False           False
# 32557  False      False  False      False          False           False
# 32558  False      False  False      False          False           False
# 32559  False      False  False      False          False           False
# 32560  False      False  False      False          False           False
#
#        occupation  relationship   race    sex  capital-gain  capital-loss  \
# ...

# %%
df.isna().sum()   #it tells how many na values are there in each column
# Out:
# age                  0
# workclass         1836
# fnwgt                0
# education            0
# education-num        0
# martial-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# target               0
# dtype: int64

# %%
df.dropna(axis=0, inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#        age          workclass   fnwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 30157   27            Private  257302   Assoc-acdm             12
# 30158   40            Private  154374      HS-grad              9
# 30159   58            Private  151910      HS-grad              9
# 30160   22            Private  201490      HS-grad              9
# 30161   52       Self-emp-inc  287927      HS-grad              9
#
#             martial-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
plt.scatter(df.age,df['hours-per-week'])
plt.show()

# %%
sns.regplot(df.age,df['hours-per-week'])  #the below figure we can see the line
plt.show()
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(df.age,df['hours-per-week'])
plt.show()
# Out:
# C:\Users\tyate\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(df)            #we can see the all pair plot of graph

# %%
df.corr()          #here corr means how closely related between them
                   #corr means corr co-relation
# Out:
#                      age     fnwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076511       0.043526      0.080154      0.060165
# fnwgt          -0.076511  1.000000      -0.044992      0.000422     -0.009750
# education-num   0.043526 -0.044992       1.000000      0.124416      0.079646
# capital-gain    0.080154  0.000422       0.124416      1.000000     -0.032229
# capital-loss    0.060165 -0.009750       0.079646     -0.032229      1.000000
# hours-per-week  0.101599 -0.022886       0.152522      0.080432      0.052417
#
#                 hours-per-week
# age                   0.101599
# fnwgt                -0.022886
# education-num         0.152522
# capital-gain          0.080432
# capital-loss          0.052417
# hours-per-week        1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.mean()
# Out:
# C:\Users\tyate\AppData\Local\Temp\ipykernel_11248\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# age                   38.437902
# fnwgt             189793.833930
# education-num         10.121312
# capital-gain        1092.007858
# capital-loss          88.372489
# hours-per-week        40.931238
# dtype: float64

# %%
df.var()
# Out:
# C:\Users\tyate\AppData\Local\Temp\ipykernel_11248\1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# age               1.725194e+02
# fnwgt             1.116255e+10
# education-num     6.502474e+00
# capital-gain      5.485397e+07
# capital-loss      1.634572e+05
# hours-per-week    1.435200e+02
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\tyate\AppData\Local\Temp\ipykernel_11248\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# age                   13.134665
# fnwgt             105652.971529
# education-num          2.549995
# capital-gain        7406.346497
# capital-loss         404.298370
# hours-per-week        11.979984
# dtype: float64

# %%
df.groupby('sex').mean()
# Out:
#                age          fnwgt  education-num  capital-gain  capital-loss  \
# sex
#  Female  36.883459  185926.150480      10.098651    570.176753     60.938765
#  Male    39.184004  191650.246075      10.132188   1342.476546    101.540137
#
#          hours-per-week
# sex
#  Female       36.932222
#  Male         42.850687

# %%
df.groupby('sex').count()
# Out:
#            age  workclass  fnwgt  education  education-num  martial-status  \
# sex
#  Female   9782       9782   9782       9782           9782            9782
#  Male    20380      20380  20380      20380          20380           20380
#
#          occupation  relationship   race  capital-gain  capital-loss  \
# sex
#  Female        9782          9782   9782          9782          9782
#  Male         20380         20380  20380         20380         20380
#
#          hours-per-week  native-country  target
# sex
#  Female            9782            9782    9782
#  Male             20380           20380   20380

# %%
df
# Out:
#        age          workclass   fnwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 30157   27            Private  257302   Assoc-acdm             12
# 30158   40            Private  154374      HS-grad              9
# 30159   58            Private  151910      HS-grad              9
# 30160   22            Private  201490      HS-grad              9
# 30161   52       Self-emp-inc  287927      HS-grad              9
#
#             martial-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.groupby('martial-status').mean()
# Out:
#                               age          fnwgt  education-num  capital-gain  \
# martial-status
#  Divorced               42.874703  185663.029900      10.074039    753.148078
#  Married-AF-spouse      30.666667  186159.238095      10.142857    347.523810
#  Married-civ-spouse     42.770281  186499.041593      10.341557   1760.062993
#  Married-spouse-absent  40.302703  194416.532432       9.191892    657.272973
#  Never-married          28.461444  195702.779663      10.009870    383.834362
#  Separated              39.397231  207457.194888       9.384452    573.953142
#  Widowed                57.750907  175353.795647       9.178960    587.043531
#
#                         capital-loss  hours-per-week
# martial-status
#  Divorced                  66.401519       41.522069
#  Married-AF-spouse          0.000000       44.238095
#  Married-civ-spouse       123.564735       43.797156
#  Married-spouse-absent     49.964865       39.859459
# ...

# %%
pd.crosstab(df['martial-status'],df['target'])
# Out:
# target                   <=50K   >50K
# martial-status
#  Divorced                 3762    452
#  Married-AF-spouse          11     10
#  Married-civ-spouse       7666   6399
#  Married-spouse-absent     339     31
#  Never-married            9256    470
#  Separated                 873     66
#  Widowed                   747     80

# %%
df.groupby('race').mean()
# Out:
#                            age          fnwgt  education-num  capital-gain  \
# race
#  Amer-Indian-Eskimo  36.737762  123491.944056       9.356643    660.290210
#  Asian-Pac-Islander  37.910615  159337.400000      11.025698   1304.375419
#  Black               37.860845  228807.455449       9.530706    604.722045
#  Other               33.601732  195772.238095       8.683983   1060.653680
#  White               38.580612  187285.002159      10.175491   1142.651024
#
#                      capital-loss  hours-per-week
# race
#  Amer-Indian-Eskimo     37.164336       40.426573
#  Asian-Pac-Islander     91.683799       40.500559
#  Black                  56.267661       38.674476
#  Other                  50.294372       40.112554
#  White                  92.649558       41.204103

# %%
pd.crosstab(df['race'],df['target'])
# Out:
# target                <=50K   >50K
# race
#  Amer-Indian-Eskimo     252     34
#  Asian-Pac-Islander     647    248
#  Black                 2451    366
#  Other                  210     21
#  White                19094   6839

# %%
df
# Out:
#        age          workclass   fnwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 30157   27            Private  257302   Assoc-acdm             12
# 30158   40            Private  154374      HS-grad              9
# 30159   58            Private  151910      HS-grad              9
# 30160   22            Private  201490      HS-grad              9
# 30161   52       Self-emp-inc  287927      HS-grad              9
#
#             martial-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
cat_cols=["workclass","education","martial-status","occupation","relationship","race","sex","native-country","target"]

# %%
le.fit(df['sex'])
le.transform(df['sex'])
# Out:
# array([1, 1, 1, ..., 0, 1, 0])

# %%
df.sex
# Out:
# 0           Male
# 1           Male
# 2           Male
# 3           Male
# 4         Female
#           ...
# 30157     Female
# 30158       Male
# 30159     Female
# 30160       Male
# 30161     Female
# Name: sex, Length: 30162, dtype: object

# %%
for cols in cat_cols:
    le.fit(df[cols])
    df[cols]=le.transform(df[cols])

# %%
df
# Out:
#        age  workclass   fnwgt  education  education-num  martial-status  \
# 0       39          5   77516          9             13               4
# 1       50          4   83311          9             13               2
# 2       38          2  215646         11              9               0
# 3       53          2  234721          1              7               2
# 4       28          2  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 30157   27          2  257302          7             12               2
# 30158   40          2  154374         11              9               2
# 30159   58          2  151910         11              9               6
# 30160   22          2  201490         11              9               4
# 30161   52          3  287927         11              9               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
x=df.drop('target',axis=1)
y=df['target']

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 30157    0
# 30158    1
# 30159    0
# 30160    0
# 30161    1
# Name: target, Length: 30162, dtype: int32

# %%
x
# Out:
#        age  workclass   fnwgt  education  education-num  martial-status  \
# 0       39          5   77516          9             13               4
# 1       50          4   83311          9             13               2
# 2       38          2  215646         11              9               0
# 3       53          2  234721          1              7               2
# 4       28          2  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 30157   27          2  257302          7             12               2
# 30158   40          2  154374         11              9               2
# 30159   58          2  151910         11              9               6
# 30160   22          2  201490         11              9               4
# 30161   52          3  287927         11              9               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
sc.fit(x)
# Out:
# StandardScaler()

# %%
x=sc.transform(x)

# %%
x.shape
# Out:
# (30162, 14)

# %%
x
# Out:
# array([[ 0.04279571,  2.93600035, -1.0627216 , ..., -0.21858598,
#         -0.07773411,  0.26492394],
#        [ 0.88028814,  1.88768202, -1.00787131, ..., -0.21858598,
#         -2.3315307 ,  0.26492394],
#        [-0.03333996, -0.20895464,  0.24469349, ..., -0.21858598,
#         -0.07773411,  0.26492394],
#        ...,
#        [ 1.48937355, -0.20895464, -0.3585745 , ..., -0.21858598,
#         -0.07773411,  0.26492394],
#        [-1.25151078, -0.20895464,  0.11070545, ..., -0.21858598,
#         -1.74721307,  0.26492394],
#        [ 1.0325595 ,  0.83936369,  0.92884082, ..., -0.21858598,
#         -0.07773411,  0.26492394]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_train.shape
# Out:
# (21113, 14)

# %%
y_train.shape
# Out:
# (21113,)

# %%
x_test.shape
# Out:
# (9049, 14)
